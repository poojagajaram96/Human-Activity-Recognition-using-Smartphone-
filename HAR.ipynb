# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Gajaram.Pooja\\Downloads'

# %%
os.chdir("C:/Users/Gajaram.Pooja/Downloads")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Gajaram.Pooja\\Downloads'

# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt
import seaborn as sb
from scipy.stats.stats import pearsonr

# %%
data=pd.read_csv('har.csv')
data
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# 5              0.279220          -0.018620          -0.113902
# 6              0.279746          -0.018271          -0.104000
# 7              0.274601          -0.025035          -0.116831
# 8              0.272529          -0.020954          -0.114472
# 9              0.275746          -0.010372          -0.099776
# 10             0.278596          -0.015232          -0.098908
# 11             0.279152          -0.021879          -0.109731
# 12             0.274544          -0.023145          -0.112540
# 13             0.269066          -0.027686          -0.110178
# ...

# %%
data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
data.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
# tBodyAcc-std()-Z                        0
# tBodyAcc-mad()-X                        0
# tBodyAcc-mad()-Y                        0
# tBodyAcc-mad()-Z                        0
# tBodyAcc-max()-X                        0
# tBodyAcc-max()-Y                        0
# tBodyAcc-max()-Z                        0
# tBodyAcc-min()-X                        0
# tBodyAcc-min()-Y                        0
# tBodyAcc-min()-Z                        0
# tBodyAcc-sma()                          0
# tBodyAcc-energy()-X                     0
# tBodyAcc-energy()-Y                     0
# tBodyAcc-energy()-Z                     0
# tBodyAcc-iqr()-X                        0
# tBodyAcc-iqr()-Y                        0
# tBodyAcc-iqr()-Z                        0
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder=LabelEncoder()
data['Activity']=labelencoder.fit_transform(data['Activity'])
data
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# 5              0.279220          -0.018620          -0.113902
# 6              0.279746          -0.018271          -0.104000
# 7              0.274601          -0.025035          -0.116831
# 8              0.272529          -0.020954          -0.114472
# 9              0.275746          -0.010372          -0.099776
# 10             0.278596          -0.015232          -0.098908
# 11             0.279152          -0.021879          -0.109731
# 12             0.274544          -0.023145          -0.112540
# 13             0.269066          -0.027686          -0.110178
# ...

# %%
corr=data.corr()

# %%
corr
# Out:
#                                       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# tBodyAcc-mean()-X                              1.000000           0.040850
# tBodyAcc-mean()-Y                              0.040850           1.000000
# tBodyAcc-mean()-Z                             -0.129483           0.226527
# tBodyAcc-std()-X                               0.017300          -0.053834
# tBodyAcc-std()-Y                              -0.001488          -0.058448
# tBodyAcc-std()-Z                              -0.007886          -0.076509
# tBodyAcc-mad()-X                               0.023101          -0.052112
# tBodyAcc-mad()-Y                              -0.001660          -0.061261
# tBodyAcc-mad()-Z                              -0.009865          -0.081272
# tBodyAcc-max()-X                               0.056300          -0.046999
# tBodyAcc-max()-Y                              -0.004676           0.039348
# ...

# %%
sb.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
features=data.drop(columns = ['Activity', 'subject'])

# %%
features
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# 5              0.279220          -0.018620          -0.113902
# 6              0.279746          -0.018271          -0.104000
# 7              0.274601          -0.025035          -0.116831
# 8              0.272529          -0.020954          -0.114472
# 9              0.275746          -0.010372          -0.099776
# 10             0.278596          -0.015232          -0.098908
# 11             0.279152          -0.021879          -0.109731
# 12             0.274544          -0.023145          -0.112540
# 13             0.269066          -0.027686          -0.110178
# ...

# %%
labels=data['Activity']

# %%
labels
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
# 5       2
# 6       2
# 7       2
# 8       2
# 9       2
# 10      2
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      2
# 17      2
# 18      2
# 19      2
# 20      2
# 21      2
# 22      2
# 23      2
# 24      2
# 25      2
# 26      2
# 27      2
# 28      2
# 29      2
#        ..
# 2907    4
# 2908    5
# 2909    5
# 2910    5
# 2911    5
# 2912    5
# 2913    5
# 2914    5
# 2915    5
# 2916    5
# 2917    5
# 2918    5
# 2919    5
# 2920    5
# 2921    5
# 2922    5
# 2923    5
# 2924    5
# 2925    5
# 2926    5
# 2927    5
# 2928    4
# 2929    4
# 2930    4
# 2931    4
# 2932    4
# 2933    4
# 2934    4
# 2935    4
# 2936    4
# Name: Activity, Length: 2937, dtype: int32

# %%
data['Activity'].value_counts()
# Out:
# 0    537
# 2    532
# 3    496
# 1    491
# 5    461
# 4    420
# Name: Activity, dtype: int64

# %% [markdown]
# # spliting training and testing data set(60-40)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(features,labels,test_size=0.4,random_state=0)

# %%
x_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 250            0.329154          -0.034418          -0.115076
# 2928           0.392804          -0.017788          -0.090166
# 1673           0.244924          -0.094474          -0.160866
# 1835           0.336843          -0.073423          -0.149043
# 1045           0.295965          -0.064145          -0.171807
# 31             0.296487          -0.014685          -0.139808
# 2743           0.265326          -0.148912          -0.115542
# 864            0.329007          -0.035684          -0.149645
# 2772           0.426819           0.061130           0.092336
# 1560           0.278045          -0.017706          -0.110424
# 1794           0.274053          -0.032029          -0.068393
# 842            0.286491           0.001642          -0.075571
# 2248           0.271866          -0.022211          -0.069811
# 1846           0.400903          -0.028269          -0.136233
# ...

# %% [markdown]
# # logistic

# %%
from sklearn.linear_model.logistic import LogisticRegression
lgsr=LogisticRegression(random_state=0)
lgsr.fit(x_train,y_train)
# Out:
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=lgsr.predict(x_test)
y_pred
# Out:
# array([4, 2, 3, ..., 4, 5, 2])

# %%
from sklearn.metrics import confusion_matrix
conf_matrix=confusion_matrix(y_pred,y_test)
conf_matrix
# Out:
# array([[212,   1,   0,   0,   0,   0],
#        [  0, 183,  10,   0,   0,   0],
#        [  0,   6, 206,   0,   0,   0],
#        [  0,   0,   0, 203,   2,   0],
#        [  0,   0,   0,   1, 155,   0],
#        [  0,   2,   0,   0,   1, 193]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
acc_sco=accuracy_score(y_test,y_pred)
acc_sco
# Out:
# 0.9804255319148936

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
sc=SVC(kernel='rbf')
sc_classifier=sc.fit(x_train,y_train)
# Out:
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
svc_y_test=sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# [4 2 3 ... 4 5 2]

# %%
from sklearn.metrics import confusion_matrix
svc_cm_test=confusion_matrix(y_test,svc_y_test)
svc_cm_test
# Out:
# array([[212,   0,   0,   0,   0,   0],
#        [  0, 169,  21,   0,   0,   2],
#        [  0,  28, 188,   0,   0,   0],
#        [  0,   0,   0, 202,   1,   1],
#        [  0,   0,   0,   3, 136,  19],
#        [  0,   0,   0,   1,   0, 192]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
svc_acc_test=accuracy_score(y_test,svc_y_test)
svc_acc_test
# Out:
# 0.9353191489361702

# %% [markdown]
# # Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_clf=DecisionTreeClassifier()
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dtc_y_test=dtc_clf.predict(x_test)
print(dtc_y_test)
# Out:
# [4 2 3 ... 3 4 2]

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
dtc_cm_test=confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[212,   0,   0,   0,   0,   0],
#        [  0, 169,  22,   1,   0,   0],
#        [  0,  18, 198,   0,   0,   0],
#        [  0,   0,   0, 186,   5,  13],
#        [  0,   0,   0,   5, 148,   5],
#        [  0,   0,   0,   4,  11, 178]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
dtc_acc_test=accuracy_score(y_test,dtc_y_test)
dtc_acc_test
# Out:
# 0.9285106382978724

# %% [markdown]
# # Random Forest

# %%
#build random forest classifier
from sklearn.ensemble import RandomForestClassifier
rmf=RandomForestClassifier(max_depth=3,random_state=0)
rf_classi=RandomForestClassifier()
rf_classi.fit(x_train,y_train)
# Out:
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf_classi_y_test=dtc_clf.predict(x_test)
rf_classi_y_test
# Out:
# array([4, 2, 3, ..., 3, 4, 2])

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
rf_cm_test=confusion_matrix(y_test,rf_classi_y_test)
rf_cm_test
# Out:
# array([[212,   0,   0,   0,   0,   0],
#        [  0, 169,  22,   1,   0,   0],
#        [  0,  18, 198,   0,   0,   0],
#        [  0,   0,   0, 186,   5,  13],
#        [  0,   0,   0,   5, 148,   5],
#        [  0,   0,   0,   4,  11, 178]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
rf_acc_test=accuracy_score(y_test,rf_classi_y_test)
rf_acc_test
# Out:
# 0.9285106382978724

# %% [markdown]
# # Naive Baye's

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(x_train,y_train)
GaussianNB()
print(clf.predict(x_test))
# Out:
# [4 1 3 ... 4 5 2]

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
nb_cm_test=confusion_matrix(y_test,clf.predict(x_test))
nb_cm_test
# Out:
# array([[207,   1,   0,   0,   0,   4],
#        [  1, 174,  12,   0,   0,   5],
#        [  0, 144,  66,   0,   0,   6],
#        [  0,   0,   0, 160,  20,  24],
#        [  0,   0,   0,   9, 122,  27],
#        [  0,   0,   0,   4,  12, 177]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
nb_acc_test=accuracy_score(y_test,clf.predict(x_test))
nb_acc_test
# Out:
# 0.7710638297872341

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train,y_train)
y_predict=classifier.predict(x_test)

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
knn_cm_test=confusion_matrix(y_test,classifier.predict(x_test))
knn_cm_test
# Out:
# array([[212,   0,   0,   0,   0,   0],
#        [  0, 177,  13,   0,   0,   2],
#        [  0,  33, 183,   0,   0,   0],
#        [  0,   0,   0, 203,   1,   0],
#        [  0,   0,   0,   6, 150,   2],
#        [  0,   0,   0,   0,   0, 193]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
knn_acc_test=accuracy_score(y_test,classifier.predict(x_test))
knn_acc_test
# Out:
# 0.9514893617021276

# %% [markdown]
# # spliting training and testing data(80-20)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(features,labels,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 478            0.275664          -0.017385          -0.105745
# 2358           0.460134           0.023488          -0.110161
# 2888           0.287044          -0.056452          -0.139424
# 879            0.262846          -0.055336          -0.116899
# 2341           0.191632          -0.047057          -0.210377
# 1537           0.263254          -0.031231          -0.139385
# 2720           0.316208          -0.011571          -0.149072
# 1476           0.270615           0.021747          -0.114030
# 2134           0.315126          -0.007694          -0.167760
# 1580           0.275397          -0.021172          -0.105233
# 1815           0.243275          -0.025471          -0.142450
# 2331           0.212883          -0.040077          -0.160766
# 1867           0.274102          -0.027390          -0.106713
# 1455           0.209648           0.001668          -0.097652
# ...

# %% [markdown]
# # logistic

# %%
from sklearn.linear_model.logistic import LogisticRegression
lgsr=LogisticRegression(random_state=0)
lgsr.fit(X_train,y_train)
# Out:
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=lgsr.predict(X_test)
y_pred
# Out:
# array([4, 2, 3, 0, 5, 2, 4, 3, 2, 1, 4, 5, 3, 2, 2, 1, 5, 0, 0, 4, 1, 4,
#        2, 5, 3, 3, 5, 5, 2, 5, 2, 0, 0, 4, 2, 3, 0, 0, 0, 1, 4, 3, 4, 2,
#        5, 3, 5, 2, 3, 4, 2, 5, 5, 0, 1, 0, 3, 3, 2, 1, 2, 4, 2, 3, 3, 4,
#        4, 2, 2, 3, 2, 3, 4, 3, 2, 0, 2, 1, 0, 3, 2, 0, 1, 2, 5, 3, 3, 5,
#        5, 4, 4, 2, 3, 2, 1, 5, 2, 0, 3, 2, 4, 5, 4, 1, 0, 0, 1, 3, 1, 4,
#        0, 2, 5, 2, 5, 0, 0, 2, 3, 4, 3, 3, 1, 5, 3, 1, 3, 1, 0, 5, 2, 1,
#        5, 1, 0, 3, 1, 4, 1, 0, 1, 2, 0, 0, 0, 3, 0, 1, 2, 5, 1, 1, 1, 0,
#        5, 0, 5, 1, 1, 0, 2, 0, 0, 1, 1, 1, 1, 3, 2, 1, 4, 3, 3, 0, 4, 1,
#        5, 5, 5, 1, 5, 3, 1, 3, 0, 1, 5, 0, 2, 5, 4, 1, 3, 0, 1, 0, 4, 5,
#        4, 5, 1, 3, 1, 3, 4, 2, 4, 0, 5, 0, 0, 1, 3, 2, 5, 2, 2, 3, 3, 5,
#        0, 4, 0, 5, 5, 2, 0, 3, 1, 1, 4, 2, 0, 4, 0, 3, 1, 5, 2, 0, 2, 1,
#        2, 4, 0, 5, 5, 1, 2, 5, 2, 1, 5, 0, 2, 0, 5, 5, 0, 0, 4, 2, 5, 4,
#        3, 1, 1, 4, 1, 2, 2, 0, 2, 5, 0, 4, 1, 2, 2, 3, 0, 3, 0, 1, 1, 4,
# ...

# %%
from sklearn.metrics import confusion_matrix
conf_matrix=confusion_matrix(y_pred,y_test)
conf_matrix
# Out:
# array([[105,   0,   0,   0,   0,   0],
#        [  0,  92,   4,   0,   0,   0],
#        [  0,   3, 110,   0,   0,   0],
#        [  0,   0,   0, 101,   1,   0],
#        [  0,   0,   0,   0,  78,   0],
#        [  0,   1,   0,   0,   0,  93]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
acc_sco=accuracy_score(y_test,y_pred)
acc_sco
# Out:
# 0.9846938775510204

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
sc=SVC(kernel='rbf')
sc_classifier=sc.fit(X_train,y_train)
# Out:
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
svc_y_test=sc_classifier.predict(X_test)
print(svc_y_test)
# Out:
# [4 2 3 0 5 2 4 3 2 1 4 5 3 2 2 1 5 0 0 4 1 5 2 5 3 3 5 5 2 5 2 0 0 4 2 3 0
#  0 0 2 4 3 4 2 5 3 5 2 3 4 2 5 5 0 1 0 3 3 2 2 1 4 2 3 3 4 4 2 2 3 1 3 3 3
#  2 0 1 1 0 3 2 0 1 2 5 3 3 5 5 4 4 2 3 2 1 5 2 0 3 2 4 5 3 1 0 0 1 3 2 4 0
#  2 5 2 5 0 0 1 3 4 3 3 1 5 3 1 3 1 0 5 2 2 5 1 0 3 1 4 1 0 2 1 0 0 0 3 0 1
#  2 5 1 1 2 0 5 0 5 1 1 0 2 0 0 1 1 1 1 3 1 1 5 3 3 0 4 1 5 5 5 2 5 3 1 3 0
#  1 5 0 2 5 4 1 3 0 1 0 4 5 4 5 2 3 1 3 4 2 4 0 5 0 0 1 3 2 5 2 2 3 3 5 0 4
#  0 5 5 2 0 3 1 1 4 2 0 4 0 3 1 5 2 0 2 1 2 4 0 5 5 1 2 5 2 1 5 0 2 0 5 5 0
#  0 4 1 5 4 3 1 1 4 1 1 2 0 2 5 0 4 1 2 2 3 0 3 0 2 1 4 3 1 3 5 5 2 4 2 0 4
#  3 5 2 2 3 2 4 4 2 0 4 5 5 5 3 3 5 5 2 4 0 1 1 5 5 4 1 0 3 3 3 0 5 4 3 1 3
#  1 0 0 3 1 1 4 1 0 0 2 3 5 5 5 2 1 2 0 0 2 2 3 2 2 2 3 2 4 3 1 2 0 5 1 2 1
#  2 3 2 2 0 0 0 4 3 3 3 4 4 2 1 2 0 4 1 2 0 2 4 1 0 5 3 5 3 0 5 5 2 2 0 1 2
#  3 2 5 5 2 0 2 2 1 5 1 0 5 4 1 5 0 5 2 2 5 4 2 2 5 3 3 5 3 1 0 5 0 3 3 4 3
# ...

# %%
from sklearn.metrics import confusion_matrix
svc_cm_test=confusion_matrix(y_test,svc_y_test)
svc_cm_test
# Out:
# array([[105,   0,   0,   0,   0,   0],
#        [  0,  83,  12,   0,   0,   1],
#        [  0,  13, 101,   0,   0,   0],
#        [  0,   0,   0, 101,   0,   0],
#        [  0,   0,   0,   3,  68,   8],
#        [  0,   0,   0,   0,   0,  93]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
svc_acc_test=accuracy_score(y_test,svc_y_test)
svc_acc_test
# Out:
# 0.9370748299319728

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_clf=DecisionTreeClassifier()
dtc_clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dtc_y_test=dtc_clf.predict(X_test)
print(dtc_y_test)
# Out:
# [4 1 3 0 5 2 4 3 2 1 4 5 3 2 2 1 5 0 0 4 1 4 2 5 3 3 5 5 1 5 2 0 0 4 2 3 0
#  0 0 1 4 3 4 2 5 3 5 2 3 4 2 5 5 0 1 0 3 3 2 2 2 4 1 3 3 4 4 2 2 3 2 3 4 3
#  2 0 2 2 0 5 2 0 1 2 5 3 3 5 5 4 4 2 3 2 1 5 2 0 3 2 4 5 4 2 0 0 1 3 2 4 0
#  2 5 2 1 0 0 2 3 4 3 3 1 5 3 1 3 1 0 5 2 1 5 1 0 3 1 4 1 0 1 2 0 0 0 4 0 1
#  2 5 1 1 1 0 5 0 5 1 1 0 2 0 0 2 2 1 1 3 2 1 5 3 3 0 4 2 5 5 5 1 5 3 1 3 0
#  1 5 0 2 5 4 1 3 0 1 0 4 5 4 5 2 3 1 3 4 2 5 0 5 0 0 2 3 2 3 2 2 3 3 5 0 4
#  0 5 5 2 0 3 1 1 4 1 0 4 0 3 1 5 2 0 2 1 2 4 0 5 3 1 2 5 2 1 5 0 2 0 5 5 0
#  0 4 2 5 4 3 1 1 4 1 1 1 0 2 5 0 4 1 2 2 3 0 3 0 1 1 4 3 2 3 5 5 2 4 2 0 4
#  3 5 2 2 3 2 4 4 1 0 4 5 5 5 3 3 5 5 1 4 0 1 2 5 5 4 1 0 3 3 3 0 5 4 3 1 3
#  1 0 0 3 1 1 4 1 0 0 2 3 5 5 5 2 1 2 0 0 2 2 3 2 2 2 3 2 4 3 1 2 0 5 1 2 1
#  2 3 2 2 0 0 0 4 3 3 3 4 4 2 1 2 0 5 1 2 0 2 4 2 0 5 3 5 3 0 5 5 2 2 0 1 1
#  3 2 4 5 2 0 2 2 1 5 1 0 5 4 1 4 0 5 2 1 5 4 2 2 5 3 3 5 5 1 0 5 0 3 3 4 3
# ...

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
dtc_cm_test=confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[105,   0,   0,   0,   0,   0],
#        [  0,  85,  11,   0,   0,   0],
#        [  0,  11, 103,   0,   0,   0],
#        [  0,   0,   0,  99,   0,   2],
#        [  0,   0,   0,   1,  75,   3],
#        [  0,   0,   1,   3,   0,  89]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
dtc_acc_test=accuracy_score(y_test,dtc_y_test)
dtc_acc_test
# Out:
# 0.9455782312925171

# %%
#build random forest classifier
from sklearn.ensemble import RandomForestClassifier
rmf=RandomForestClassifier(max_depth=3,random_state=0)
rf_classi=RandomForestClassifier()
rf_classi.fit(X_train,y_train)
# Out:
# C:\Users\Gajaram.Pooja\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf_classi_y_test=dtc_clf.predict(X_test)
rf_classi_y_test
# Out:
# array([4, 1, 3, 0, 5, 2, 4, 3, 2, 1, 4, 5, 3, 2, 2, 1, 5, 0, 0, 4, 1, 4,
#        2, 5, 3, 3, 5, 5, 1, 5, 2, 0, 0, 4, 2, 3, 0, 0, 0, 1, 4, 3, 4, 2,
#        5, 3, 5, 2, 3, 4, 2, 5, 5, 0, 1, 0, 3, 3, 2, 2, 2, 4, 1, 3, 3, 4,
#        4, 2, 2, 3, 2, 3, 4, 3, 2, 0, 2, 2, 0, 5, 2, 0, 1, 2, 5, 3, 3, 5,
#        5, 4, 4, 2, 3, 2, 1, 5, 2, 0, 3, 2, 4, 5, 4, 2, 0, 0, 1, 3, 2, 4,
#        0, 2, 5, 2, 1, 0, 0, 2, 3, 4, 3, 3, 1, 5, 3, 1, 3, 1, 0, 5, 2, 1,
#        5, 1, 0, 3, 1, 4, 1, 0, 1, 2, 0, 0, 0, 4, 0, 1, 2, 5, 1, 1, 1, 0,
#        5, 0, 5, 1, 1, 0, 2, 0, 0, 2, 2, 1, 1, 3, 2, 1, 5, 3, 3, 0, 4, 2,
#        5, 5, 5, 1, 5, 3, 1, 3, 0, 1, 5, 0, 2, 5, 4, 1, 3, 0, 1, 0, 4, 5,
#        4, 5, 2, 3, 1, 3, 4, 2, 5, 0, 5, 0, 0, 2, 3, 2, 3, 2, 2, 3, 3, 5,
#        0, 4, 0, 5, 5, 2, 0, 3, 1, 1, 4, 1, 0, 4, 0, 3, 1, 5, 2, 0, 2, 1,
#        2, 4, 0, 5, 3, 1, 2, 5, 2, 1, 5, 0, 2, 0, 5, 5, 0, 0, 4, 2, 5, 4,
#        3, 1, 1, 4, 1, 1, 1, 0, 2, 5, 0, 4, 1, 2, 2, 3, 0, 3, 0, 1, 1, 4,
# ...

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
rf_cm_test=confusion_matrix(y_test,rf_classi_y_test)
rf_cm_test
# Out:
# array([[105,   0,   0,   0,   0,   0],
#        [  0,  85,  11,   0,   0,   0],
#        [  0,  11, 103,   0,   0,   0],
#        [  0,   0,   0,  99,   0,   2],
#        [  0,   0,   0,   1,  75,   3],
#        [  0,   0,   1,   3,   0,  89]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
rf_acc_test=accuracy_score(y_test,rf_classi_y_test)
rf_acc_test
# Out:
# 0.9455782312925171

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(X_train,y_train)
GaussianNB()
print(clf.predict(X_test))
# Out:
# [4 1 3 0 5 5 4 3 1 2 3 5 3 2 1 1 5 0 0 4 1 5 1 5 4 5 5 5 2 5 2 0 0 4 2 3 0
#  0 0 1 4 3 4 2 5 5 5 2 3 4 1 5 5 0 1 0 5 3 1 1 1 4 5 5 3 5 4 1 2 5 1 5 3 4
#  2 0 1 1 0 5 1 0 1 2 5 3 3 5 4 4 4 1 3 1 1 5 2 0 3 1 4 5 3 1 0 0 1 3 1 4 0
#  2 5 1 5 0 0 1 4 4 3 3 1 5 3 1 3 2 0 5 1 1 5 1 0 3 1 4 1 0 1 1 0 0 0 3 0 1
#  2 5 1 1 2 0 5 0 5 1 1 0 1 0 0 1 1 1 1 3 1 1 5 3 3 0 4 1 5 4 5 1 5 3 1 3 0
#  1 5 0 2 5 4 1 3 0 1 5 4 5 4 5 2 3 1 3 4 2 4 0 4 0 0 1 3 1 5 2 1 3 3 5 0 4
#  0 5 5 2 0 5 1 2 4 1 0 4 5 4 1 5 1 0 2 1 2 4 0 5 5 1 2 5 1 1 5 0 2 0 5 5 0
#  0 4 1 5 4 4 1 5 4 1 1 1 0 2 5 0 4 1 1 1 3 0 3 0 1 1 4 5 1 3 5 5 2 4 5 0 5
#  3 5 1 5 3 1 4 4 2 0 3 5 5 5 3 3 5 5 2 4 0 1 1 5 5 4 1 0 3 3 3 0 5 4 3 1 3
#  1 0 0 3 1 1 4 1 0 0 1 3 5 5 5 1 1 2 0 0 1 1 3 1 2 1 3 1 4 3 1 1 0 3 1 2 1
#  1 4 1 2 0 0 0 5 3 3 3 4 4 2 1 2 0 5 1 1 0 2 4 2 0 5 3 5 3 0 5 5 1 2 0 1 1
#  5 1 5 5 1 0 1 1 2 5 2 0 5 4 1 5 0 5 1 2 5 4 1 1 5 3 3 5 4 1 0 5 0 3 4 4 3
# ...

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
nb_cm_test=confusion_matrix(y_test,clf.predict(X_test))
nb_cm_test
# Out:
# array([[102,   0,   0,   0,   0,   3],
#        [  0,  84,   9,   0,   0,   3],
#        [  0,  70,  39,   0,   0,   5],
#        [  0,   0,   0,  77,   9,  15],
#        [  0,   0,   0,   6,  58,  15],
#        [  0,   0,   0,   2,   3,  88]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
nb_acc_test=accuracy_score(y_test,clf.predict(X_test))
nb_acc_test
# Out:
# 0.7619047619047619

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train,y_train)
y_predict=classifier.predict(X_test)

# %%
#Build confusion matrix on test
from sklearn.metrics import confusion_matrix
knn_cm_test=confusion_matrix(y_test,classifier.predict(X_test))
knn_cm_test
# Out:
# array([[105,   0,   0,   0,   0,   0],
#        [  0,  90,   6,   0,   0,   0],
#        [  0,  13, 101,   0,   0,   0],
#        [  0,   0,   0, 100,   1,   0],
#        [  0,   0,   0,   4,  75,   0],
#        [  0,   0,   0,   0,   0,  93]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
knn_acc_test=accuracy_score(y_test,classifier.predict(X_test))
knn_acc_test
# Out:
# 0.9591836734693877
